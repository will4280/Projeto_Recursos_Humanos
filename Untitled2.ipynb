# %% [markdown]
# <a href="https://colab.research.google.com/github/will4280/Projeto_Recursos_Humanos/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bibliotacas para Modelagem de Matriz
import numpy
import pandas as pd

#Bibliotecas para análises gráficas
import matplotlib.pyplot as plt
import seaborn as sns

#Lib para ignorar avisos
import warnings


#Desabilitando avisos
warnings.filterwarnings('ignore')

# %%
#Lendo os Dados
Base_Dados = pd.read_csv('Salary_Data.csv')

#Verificando
Base_Dados.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
from re import U
#Renomear as colunas
Base_Dados.rename( columns={
    'YearsExperience' : 'Xp',
    'Salary': 'Renda'
}, inplace=True)

# %%
#Dimessão
Base_Dados.shape
# Out:
# (30, 2)

# %%
#Campos Nulos
Base_Dados.isnull().sum()
# Out:
# Xp       0
# Renda    0
# dtype: int64

# %%
#Grafico Nulos
sns.heatmap(Base_Dados.isnull(), cbar=False );

# %%
Base_Dados.describe()
# Out:
#               Xp          Renda
# count  30.000000      30.000000
# mean    5.313333   76003.000000
# std     2.837888   27414.429785
# min     1.100000   37731.000000
# 25%     3.200000   56720.750000
# 50%     4.700000   65237.000000
# 75%     7.700000  100544.750000
# max    10.500000  122391.000000

# %%
#Criando_Grafico
plt.figure(figsize=(10,6) )
plt.title('Análise da Renda')
sns.kdeplot( Base_Dados['Renda'], color='green');

# %%
#Criando_Grafico
plt.figure(figsize=(10,6) )
plt.title('Análise da Xp')
sns.kdeplot( Base_Dados['Xp'], color='black');

# %%
#Distribuição
plt.figure(figsize=(10,5) )
sns.boxplot( Base_Dados ['Xp'] );

# %%
#Distribuição
plt.figure(figsize=(10,5) )
sns.scatterplot(data= Base_Dados, x='Renda', y= 'Xp');

# %%
plt.figure(figsize=(10,5) )
sns.regplot(data= Base_Dados, x='Renda', y= 'Xp');

# %%
Correlacao = Base_Dados.corr()
plt.figure(figsize=(10,5) )
sns.heatmap( Correlacao, annot=True );
